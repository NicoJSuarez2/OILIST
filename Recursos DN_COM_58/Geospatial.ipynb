# %%
import numpy as np
import pandas as pd 
import os

geo = pd.read_csv(r"C:\Users\Administrador\Desktop\DATos\Ciclo 1\Recursos DN_COM_58\olist_geolocation_dataset.csv", dtype={'geolocation_zip_code_prefix': str})

# Obtiene los primeros tres y cuatro primeros dígitos de los códigos postales, exploraremos esto más a fondo para comprender cómo funcionan los códigos postalesgeo['geolocation_zip_code_prefix_1_digits'] = geo['geolocation_zip_code_prefix'].str[0:1]
# Gets the first three and four first digits of zip codes, we will explore this further to understand how zip codes works
geo['geolocation_zip_code_prefix_1_digits'] = geo['geolocation_zip_code_prefix'].str[0:1]
geo['geolocation_zip_code_prefix_2_digits'] = geo['geolocation_zip_code_prefix'].str[0:2]
geo['geolocation_zip_code_prefix_3_digits'] = geo['geolocation_zip_code_prefix'].str[0:3]
geo['geolocation_zip_code_prefix_4_digits'] = geo['geolocation_zip_code_prefix'].str[0:4]
geo.head(3)
# Out:
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state geolocation_zip_code_prefix_1_digits  \
# 0        sao paulo                SP                                    0
# 1        sao paulo                SP                                    0
# 2        sao paulo                SP                                    0
#
#   geolocation_zip_code_prefix_2_digits geolocation_zip_code_prefix_3_digits  \
# 0                                   01                                  010
# 1                                   01                                  010
# 2                                   01                                  010
#
#   geolocation_zip_code_prefix_4_digits
# 0                                 0103
# 1                                 0104
# 2                                 0104

# %%
geo['geolocation_zip_code_prefix'].value_counts().to_frame().describe()
# Out:
#               count
# count  19015.000000
# mean      52.598633
# std       72.057907
# min        1.000000
# 25%       10.000000
# 50%       29.000000
# 75%       66.500000
# max     1146.000000

# %%
# Quitamos los outliers
#Brazils most Northern spot is at 5 deg 16′ 27.8″ N latitude.;
geo = geo[geo.geolocation_lat <= 5.27438888]
#it’s most Western spot is at 73 deg, 58′ 58.19″W Long.
geo = geo[geo.geolocation_lng >= -73.98283055]
#It’s most southern spot is at 33 deg, 45′ 04.21″ S Latitude.
geo = geo[geo.geolocation_lat >= -33.75116944]
#It’s most Eastern spot is 34 deg, 47′ 35.33″ W Long.
geo = geo[geo.geolocation_lng <=  -34.79314722]

# %%
#REQUERIMIENTOS
"""%pip install datashader
# %pip install holoviews geoviews datashader  bokeh  """
# Out:
# '%pip install datashader\n%pip install holoviews geoviews datashader  bokeh  '

# %%
from datashader.utils import lnglat_to_meters as webm
x, y = webm(geo.geolocation_lng, geo.geolocation_lat)
geo['x'] = pd.Series(x)
geo['y'] = pd.Series(y)

# %%
geo.head(3)
# Out:
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state geolocation_zip_code_prefix_1_digits  \
# 0        sao paulo                SP                                    0
# 1        sao paulo                SP                                    0
# 2        sao paulo                SP                                    0
#
#   geolocation_zip_code_prefix_2_digits geolocation_zip_code_prefix_3_digits  \
# 0                                   01                                  010
# 1                                   01                                  010
# 2                                   01                                  010
#
#   geolocation_zip_code_prefix_4_digits             x             y
# 0                                 0103 -5.191862e+06 -2.698137e+06
# 1                                 0104 -5.192478e+06 -2.698193e+06
# 2                                 0104 -5.192270e+06 -2.698199e+06

# %%
# transforming the prefixes to int for plotting purposes
geo['geolocation_zip_code_prefix'] = geo['geolocation_zip_code_prefix'].astype(int)
geo['geolocation_zip_code_prefix_1_digits'] = geo['geolocation_zip_code_prefix_1_digits'].astype(int)
geo['geolocation_zip_code_prefix_2_digits'] = geo['geolocation_zip_code_prefix_2_digits'].astype(int)
geo['geolocation_zip_code_prefix_3_digits'] = geo['geolocation_zip_code_prefix_3_digits'].astype(int)
geo['geolocation_zip_code_prefix_4_digits'] = geo['geolocation_zip_code_prefix_4_digits'].astype(int)

# %%
brazil = geo
agg_name = 'geolocation_zip_code_prefix'
brazil[agg_name].describe().to_frame()
# Out:
#        geolocation_zip_code_prefix
# count                 1.000121e+06
# mean                  3.657332e+04
# std                   3.054939e+04
# min                   1.001000e+03
# 25%                   1.107500e+04
# 50%                   2.653000e+04
# 75%                   6.350400e+04
# max                   9.999000e+04

# %%
# Out:
# Collecting holoviews
#   Downloading holoviews-1.18.3-py2.py3-none-any.whl.metadata (21 kB)
# Collecting geoviews
#   Downloading geoviews-1.12.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: datashader in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (0.16.1)
# Collecting bokeh
#   Downloading bokeh-3.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from holoviews) (2.1.0)
# Requirement already satisfied: numpy>=1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from holoviews) (1.26.4)
# Collecting pyviz-comms>=0.7.4 (from holoviews)
#   Downloading pyviz_comms-3.0.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting panel>=1.0 (from holoviews)
#   Downloading panel-1.4.2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: colorcet in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from holoviews) (3.1.0)
# Requirement already satisfied: packaging in c:\users\administrador\appdata\roaming\python\python310\site-packages (from holoviews) (23.2)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from holoviews) (2.2.2)
# Collecting cartopy>=0.18.0 (from geoviews)
#   Downloading Cartopy-0.23.0-cp310-cp310-win_amd64.whl.metadata (8.2 kB)
# Collecting shapely (from geoviews)
#   Downloading shapely-2.0.4-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Collecting pyproj (from geoviews)
#   Downloading pyproj-3.6.1-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting xyzservices (from geoviews)
#   Downloading xyzservices-2024.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: dask in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (2024.4.2)
# Requirement already satisfied: multipledispatch in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (1.0.0)
# Requirement already satisfied: numba in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (0.59.1)
# Requirement already satisfied: pillow in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (10.3.0)
# Requirement already satisfied: pyct in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (1.13.0)
# Requirement already satisfied: toolz in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (0.12.1)
# Requirement already satisfied: xarray in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from datashader) (2024.3.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.2.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from bokeh) (6.4)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Collecting pyshp>=2.3 (from cartopy>=0.18.0->geoviews)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#      ------------------------------------ --- 51.2/56.0 kB ? eta -:--:--
#      ------------------------------------ --- 51.2/56.0 kB ? eta -:--:--
#      ------------------------------------ --- 51.2/56.0 kB ? eta -:--:--
#      -------------------------------------- 56.0/56.0 kB 293.2 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.20.0->holoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.20.0->holoviews) (2024.1)
# Collecting markdown (from panel>=1.0->holoviews)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting markdown-it-py (from panel>=1.0->holoviews)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting linkify-it-py (from panel>=1.0->holoviews)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from panel>=1.0->holoviews)
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting tqdm>=4.48.0 (from panel>=1.0->holoviews)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/57.6 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/57.6 kB ? eta -:--:--
#      -------------------------------------- 57.6/57.6 kB 378.5 kB/s eta 0:00:00
# Requirement already satisfied: bleach in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from panel>=1.0->holoviews) (6.1.0)
# Collecting typing-extensions (from panel>=1.0->holoviews)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: certifi in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from pyproj->geoviews) (2024.2.2)
# Requirement already satisfied: click>=8.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from dask->datashader) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from dask->datashader) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from dask->datashader) (2024.3.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from dask->datashader) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from dask->datashader) (7.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from numba->datashader) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from requests->datashader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from requests->datashader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from requests->datashader) (2.2.1)
# Requirement already satisfied: colorama in c:\users\administrador\appdata\roaming\python\python310\site-packages (from click>=8.1->dask->datashader) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.18.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (3.1.2)
# Requirement already satisfied: locket in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from partd>=1.2.0->dask->datashader) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->holoviews)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.0->holoviews)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading holoviews-1.18.3-py2.py3-none-any.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#     --------------------------------------- 0.1/4.3 MB 2.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/4.3 MB 1.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.3/4.3 MB 1.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.3/4.3 MB 1.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.4/4.3 MB 1.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/4.3 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0
9 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.0 MB/s eta 0:00:00
# Downloading xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ---------------------------------------  81.9/82.0 kB ? eta -:--:--
#    ---------------------------------------  81.9/82.0 kB ? eta -:--:--
#    ---------------------------------------- 82.0/82.0 kB 763.4 kB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/46.5 kB ? eta -:--:--
#    ---------------------------------------- 46.5/46.5 kB 58.1 kB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 217.4 kB/s eta 0:00:00
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    -------------------------------------- - 102.4/105.4 kB ? eta -:--:--
#    -------------------------------------- - 102.4/105.4 kB ? eta -:--:--
#    -------------------------------------- - 102.4/105.4 kB ? eta -:--:--
#    -------------------------------------- - 102.4/105.4 kB ? eta -:--:--
#    -------------------------------------- 105.4/105.4 kB 434.4 kB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 82.5 kB/s eta 0:00:00
# Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.1 kB ? eta -:--:--
#    ---------------------------------------- 54.1/54.1 kB 46.0 kB/s eta 0:00:00
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: xyzservices, uc-micro-py, typing-extensions, tqdm, shapely, pyviz-comms, pyshp, pyproj, mdurl, markdown, markdown-it-py, linkify-it-py, mdit-py-plugins, cartopy, bokeh, panel, holoviews, geoviews
# Successfully installed bokeh-3.4.1 cartopy-0.23.0 geoviews-1.12.0 holoviews-1.18.3 linkify-it-py-2.0.3 markdown-3.6 markdown-it-py-3.0.0 mdit-py-plugins-0.4.0 mdurl-0.1.2 panel-1.4.2 pyproj-3.6.1 pyshp-2.3.1 pyviz-comms-3.0.2 shapely-2.0.4 tqdm-4.66.4 typing-extensions-4.11.0 uc-micro-py-1.0.3 xyzservices-2024.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# plot wtih holoviews + datashader - bokeh with map background
import holoviews as hv
import geoviews as gv
import datashader as ds
from colorcet import fire, rainbow, bgy, bjy, bkr, kb, kr
from datashader.colors import colormap_select, Greys9
from holoviews.streams import RangeXY
from holoviews.operation.datashader import datashade, dynspread, rasterize
from bokeh.io import push_notebook, show, output_notebook
output_notebook()
hv.extension('bokeh')

# %opts Overlay [width=800 height=600 toolbar='above' xaxis=None yaxis=None]
# %opts QuadMesh [tools=['hover'] colorbar=True] (alpha=0 hover_alpha=0.2)

T = 0.05
PX = 1

def plot_map(data, label, agg_data, agg_name, cmap):
    url="http://server.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Dark_Gray_Base/MapServer/tile/{Z}/{Y}/{X}.png"
    geomap = gv.WMTS(url)
    points = hv.Points(gv.Dataset(data, kdims=['x', 'y'], vdims=[agg_name]))
    agg = datashade(points, element_type=gv.Image, aggregator=agg_data, cmap=cmap)
    zip_codes = dynspread(agg, threshold=T, max_px=PX)
    hover = hv.util.Dynamic(rasterize(points, aggregator=agg_data, width=50, height=25, streams=[RangeXY]), operation=hv.QuadMesh)
    hover = hover.options(cmap=cmap)
    img = geomap * zip_codes * hover
    img = img.relabel(label)
    return img
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dff6d9f4-0e94-4135-900c-f4cf6108eed3">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1009'>
#   <div id="b9cb1ccc-8fd9-4446-9ec7-5116f75f764c" data-root-id="p1009" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d757b61d-0d06-47fa-b954-e2d90042296f":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1009"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1010","attributes":{"plot_id":"p1009","comm_id":"7eb05214579240238aa7fd3452a93730","client_comm_id":"7d6bac86cf464a93af382d5800b44739"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"d757b61d-0d06-47fa-b954-e2d90042296f","roots":{"p1009":"b9cb1ccc-8fd9-4446-9ec7-5116f75f764c"},"root_ids":["p1009"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# %pip install jupyter_bokeh
# Out:
# Collecting jupyter_bokeh
#   Downloading jupyter_bokeh-4.0.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: bokeh==3.* in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from jupyter_bokeh) (3.4.1)
# Collecting ipywidgets==8.* (from jupyter_bokeh)
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from bokeh==3.*->jupyter_bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from bokeh==3.*->jupyter_bokeh) (6.4)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2024.4.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.14.0)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets==8.*->jupyter_bokeh)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets==8.*->jupyter_bokeh)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (1.2.0)
# Requirement already satisfied: colorama in c:\users\administrador\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrador\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\administrador\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.12)
# Requirement already satisfied: six>=1.5 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\administrador\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\administrador\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Downloading jupyter_bokeh-4.0.4-py3-none-any.whl (148 kB)
#    ---------------------------------------- 0.0/148.6 kB ? eta -:--:--
#    -------------------------------------- - 143.4/148.6 kB 8.9 MB/s eta 0:00:01
#    -------------------------------------- - 143.4/148.6 kB 8.9 MB/s eta 0:00:01
#    -------------------------------------- - 143.4/148.6 kB 8.9 MB/s eta 0:00:01
#    -------------------------------------- 148.6/148.6 kB 739.9 kB/s eta 0:00:00
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.4 kB ? eta -:--:--
#    -------------------------------------- 139.4/139.4 kB 393.8 kB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    ------------------------------------- - 204.8/215.0 kB 12.2 MB/s eta 0:00:01
#    ------------------------------------- - 204.8/215.0 kB 12.2 MB/s eta 0:00:01
#    ------------------------------------- - 204.8/215.0 kB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 215.0/215.0 kB 1.3 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 15.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.3 MB 17.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets, jupyter_bokeh
# Successfully installed ipywidgets-8.1.2 jupyter_bokeh-4.0.4 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plot_map(brazil, 'Zip Codes in Brazil', ds.min(agg_name), agg_name, cmap=rainbow)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'8455e961-3d9f-4b02-abfe-fa8df060aede': {'version…

# %%
# plot wtih datashader - image with black background
import datashader as ds
from datashader import transfer_functions as tf
from functools import partial
from datashader.utils import export_image
from IPython.core.display import HTML, display
from colorcet import fire, rainbow, bgy, bjy, bkr, kb, kr

background = "black"
cm = partial(colormap_select, reverse=(background!="black"))
export = partial(export_image, background = background, export_path="export")
display(HTML("<style>.container { width:100% !important; }</style>"))
W = 700 

def create_map(data, cmap, data_agg, export_name='img'):
    pad = (data.x.max() - data.x.min())/50
    x_range, y_range = ((data.x.min() - pad, data.x.max() + pad), 
                             (data.y.min() - pad, data.y.max() + pad))

    ratio = (y_range[1] - y_range[0]) / (x_range[1] - x_range[0])

    plot_width  = int(W)
    plot_height = int(plot_width * ratio)
    if ratio > 1.5:
        plot_height = 550
        plot_width = int(plot_height / ratio)
        
    cvs = ds.Canvas(plot_width=plot_width, plot_height=plot_height, x_range=x_range, y_range=y_range)

    agg = cvs.points(data, 'x', 'y', data_agg)
    img = tf.shade(agg, cmap=cmap, how='eq_hist')
    return export(img, export_name)
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_17132\2869213612.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display
# <style>.container { width:100% !important; }</style>

# %%
create_map(brazil, rainbow, ds.mean(agg_name),'brazil_zip_codes')
# Out:
# <xarray.Image (y: 738, x: 700)> Size: 2MB
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * x        (x) float64 6kB -8.2e+06 -8.194e+06 ... -3.798e+06 -3.791e+06
#   * y        (y) float64 6kB -4.069e+06 -4.063e+06 ... 5.749e+05 5.812e+05

# %%
def filter_data(level, name):
    df = geo[geo[level] == name]
    #remove outliers
    df = df[(df.x <= df.x.quantile(0.999)) & (df.x >= df.x.quantile(0.001))]
    df = df[(df.y <= df.y.quantile(0.999)) & (df.y >= df.y.quantile(0.001))]
    return df

# %%
sp = filter_data('geolocation_state', 'SP')
agg_name = 'geolocation_zip_code_prefix'
sp[agg_name].describe().to_frame()
# Out:
#        geolocation_zip_code_prefix
# count                402651.000000
# mean                   9030.831782
# std                    5101.941134
# min                    1001.000000
# 25%                    4661.000000
# 50%                    8257.000000
# 75%                   13330.000000
# max                   19990.000000

# %%
plot_map(sp, 'Zip Codes in Sao Paulo State', ds.min(agg_name), agg_name, cmap=rainbow)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'5b943bb7-2c2a-43fa-8948-b50884b03d48': {'version…

# %%
create_map(sp, rainbow, ds.mean(agg_name), 'sp_zip_codes')
# Out:
# <xarray.Image (y: 502, x: 700)> Size: 1MB
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * x        (x) float64 6kB -5.816e+06 -5.815e+06 ... -4.99e+06 -4.989e+06
#   * y        (y) float64 4kB -2.857e+06 -2.856e+06 ... -2.264e+06 -2.263e+06
